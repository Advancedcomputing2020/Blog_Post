# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df_global_temp = pd.read_csv("annual_csv.csv")
df_global_temp.head()
# Out:
#     Source  Year    Mean
# 0     GCAG  2016  0.9363
# 1  GISTEMP  2016  0.9900
# 2     GCAG  2015  0.8998
# 3  GISTEMP  2015  0.8700
# 4     GCAG  2014  0.7408

# %%
df_global_temp = df_global_temp[df_global_temp['Source'] == 'GISTEMP'].reset_index()[["Source", "Year", "Mean"]]
df_global_temp.head()
# Out:
#     Source  Year  Mean
# 0  GISTEMP  2016  0.99
# 1  GISTEMP  2015  0.87
# 2  GISTEMP  2014  0.74
# 3  GISTEMP  2013  0.65
# 4  GISTEMP  2012  0.63

# %%
df_rice_fields = pd.read_csv("rice-yields.csv")
df_rice_fields.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1961
# 1  Afghanistan  AFG  1962
# 2  Afghanistan  AFG  1963
# 3  Afghanistan  AFG  1964
# 4  Afghanistan  AFG  1965
#
#    Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha
# 0                                              10831
# 1                                              10480
# 2                                               9548
# 3                                              10461
# 4                                              10621

# %%
df_rice_fields.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha'],
#       dtype='object')

# %%
df_rice_fields.values
# Out:
# array([['Afghanistan', 'AFG', 1961, 10831],
#        ['Afghanistan', 'AFG', 1962, 10480],
#        ['Afghanistan', 'AFG', 1963, 9548],
#        ...,
#        ['Zimbabwe', 'ZWE', 2016, 4349],
#        ['Zimbabwe', 'ZWE', 2017, 6219],
#        ['Zimbabwe', 'ZWE', 2018, 5789]], dtype=object)

# %%
df_rice_fields[["Entity"]]
# Out:
#             Entity
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 11784     Zimbabwe
# 11785     Zimbabwe
# 11786     Zimbabwe
# 11787     Zimbabwe
# 11788     Zimbabwe
#
# [11789 rows x 1 columns]

# %%
df_rice_fields.rename(columns={"Entity": "Country", "Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha": "Yield"})
# Out:
#            Country Code  Year  Yield
# 0      Afghanistan  AFG  1961  10831
# 1      Afghanistan  AFG  1962  10480
# 2      Afghanistan  AFG  1963   9548
# 3      Afghanistan  AFG  1964  10461
# 4      Afghanistan  AFG  1965  10621
# ...            ...  ...   ...    ...
# 11784     Zimbabwe  ZWE  2014   8243
# 11785     Zimbabwe  ZWE  2015   5584
# 11786     Zimbabwe  ZWE  2016   4349
# 11787     Zimbabwe  ZWE  2017   6219
# 11788     Zimbabwe  ZWE  2018   5789
#
# [11789 rows x 4 columns]

# %%
df_rice_fields[["Entity","Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha"]]
# Out:
#   File "<ipython-input-17-78650610c74f>", line 1
#     df_rice_fields[["Entity","Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha": "Yield"]]
#                                                                                               ^
# SyntaxError: invalid syntax

# %%
df_rice_fields
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1961
# 1      Afghanistan  AFG  1962
# 2      Afghanistan  AFG  1963
# 3      Afghanistan  AFG  1964
# 4      Afghanistan  AFG  1965
# ...            ...  ...   ...
# 11784     Zimbabwe  ZWE  2014
# 11785     Zimbabwe  ZWE  2015
# 11786     Zimbabwe  ZWE  2016
# 11787     Zimbabwe  ZWE  2017
# 11788     Zimbabwe  ZWE  2018
#
#        Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha
# 0                                                  10831
# 1                                                  10480
# 2                                                   9548
# 3                                                  10461
# 4                                                  10621
# ...                                                  ...
# 11784                                               8243
# 11785                                               5584
# 11786                                               4349
# ...

# %%
df = df_rice_fields.rename(columns={"Entity": "Country", "Crops - Cereals (Rice Milled Eqv) - 1817 - Yield - 5419 - hg/ha": "Yield"})

# %%
df
# Out:
#            Country Code  Year  Yield
# 0      Afghanistan  AFG  1961  10831
# 1      Afghanistan  AFG  1962  10480
# 2      Afghanistan  AFG  1963   9548
# 3      Afghanistan  AFG  1964  10461
# 4      Afghanistan  AFG  1965  10621
# ...            ...  ...   ...    ...
# 11784     Zimbabwe  ZWE  2014   8243
# 11785     Zimbabwe  ZWE  2015   5584
# 11786     Zimbabwe  ZWE  2016   4349
# 11787     Zimbabwe  ZWE  2017   6219
# 11788     Zimbabwe  ZWE  2018   5789
#
# [11789 rows x 4 columns]

# %%
df[["Country","Yield"]].head()
# Out:
#        Country  Yield
# 0  Afghanistan  10831
# 1  Afghanistan  10480
# 2  Afghanistan   9548
# 3  Afghanistan  10461
# 4  Afghanistan  10621

# %%
df.loc[['India']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-0bec9077db7b> in <module>
# ----> 1 df.loc[['India']]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1035
# ...

# %%
df_india=df[df['Country']=='India']

# %%
df_india=df_india.reset_index()[["Country", "Code", "Year", 'Yield']]

# %%
df_india.head()
# Out:
#   Country Code  Year  Yield
# 0   India  IND  1961   7542
# 1   India  IND  1962   7529
# 2   India  IND  1963   7683
# 3   India  IND  1964   7854
# 4   India  IND  1965   6906

# %%
sns.set()
sns.lineplot(df_global_temp['Year'], df_global_temp['Mean'])
plt.ylabel("Mean")
plt.title("Average Global Mean Temperature and wheat production in India")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Average Global Mean Temperature and wheat production in India')

# %%
sns.lineplot(df_india['Year'], df_india['Yield'])
plt.ylabel("Mean temperature/tonnes per hectare wheat in India ")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Mean temperature/tonnes per hectare wheat in India ')

# %%
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Mean temperature/tonnes per hectare wheat in India ')

# %%
df_fossil = pd.read_csv("fossil-fuel-co2-emissions-by-nation_csv.csv")

# %%
df_fossil_india=df_fossil[df_fossil['Country']=="INDIA"]
df_fossil_india
# Out:
#        Year Country   Total  Solid Fuel  Liquid Fuel  Gas Fuel  Cement  \
# 633    1858   INDIA     119         119            0         0       0
# 652    1859   INDIA     192         192            0         0       0
# 673    1860   INDIA     194         194            0         0       0
# 695    1861   INDIA     150         150            0         0       0
# 717    1862   INDIA     166         166            0         0       0
# ...     ...     ...     ...         ...          ...       ...     ...
# 16227  2010   INDIA  468964      298209       112969     27357   29920
# 16444  2011   INDIA  502257      330199       113915     24937   32640
# 16663  2012   INDIA  550451      372453       119399     21312   36720
# 16883  2013   INDIA  554882      362676       125763     27784   38080
# 17103  2014   INDIA  610411      407077       140199     25278   37400
#
#        Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %%
sns.lineplot(df_fossil_india['Year'], df_fossil_india['Total'])
plt.ylabel("Fossil-fuel-co2-emissions-by-India")
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Fossil-fuel-co2-emissions-by-India')

# %%
df_co2_mlo=pd.read_csv("co2-mm-mlo_csv.csv")
df_co2_mlo.head()
# Out:
#          Date  Decimal Date  Average  Interpolated   Trend  Number of Days
# 0  1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1  1958-04-01      1958.292   317.45        317.45  315.29              -1
# 2  1958-05-01      1958.375   317.50        317.50  314.71              -1
# 3  1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 4  1958-07-01      1958.542   315.86        315.86  314.98              -1

# %%
dd_co2=df_co2_mlo[df_co2_mlo['Date']=='']
